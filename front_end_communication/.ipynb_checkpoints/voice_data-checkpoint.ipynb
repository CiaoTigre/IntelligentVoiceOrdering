# %%
#树莓派访问树莓派
#!/usr/bin/env python
#encoding:utf8
#author: zeping lai
# 生产者
 
import pika
import sys
import json  
import time
import numpy as np


def generate_environmental_sensor_data(i):
    Environmental_sensor={}
    Environmental_sensor["timestamp"]=int(time.time()*1000)
    Environmental_sensor["sensorID"]=i
    Environmental_sensor["temp"]=np.random.randint(30)
    Environmental_sensor["hum"]=np.random.randint(100)
    Environmental_sensor["pm2.5"]=np.random.randint(50)
    Environmental_sensor["pm10"]=np.random.randint(50)
    Environmental_sensor["co2"]=np.random.randint(100)
    return Environmental_sensor

def generate_infrared_array_sensor_data(i):
    Infrared_array_sensor={}
    Infrared_array_sensor["timestamp"]=int(time.time()*1000)
    Infrared_array_sensor["sensorID"]=i
    Infrared_array_sensor["heatCount"]=np.random.randint(8)
    Infrared_array_sensor["coordinates"]=np.random.randint(1000)
    Infrared_array_sensor["existBits"]=np.random.randint(100)
    Infrared_array_sensor["direction"]=np.random.randint(1000)
    Infrared_array_sensor["temperture"]=np.random.randint(100)
    return Environmental_sensor

mq_name =  'helab'  #RabbitMQ的用户名
mq_pwd = 'helab'  #RabbitMQ的密码
mq_host = '192.168.31.184'  # 'rabbitmq.eicp.vip'#'192.168.31.184' #RabbitMQ服务地址192.168.31.102 localhost
mq_port= 5672  #58765#  5672                #RabbitMQ服务端口

mq_queue1 = 'track'      #队列
mq_routing_key1 = 'track' #路由键
    
#身份验证凭证
credentials = pika.PlainCredentials(mq_name, mq_pwd)
 
#创建连接
s_conn = pika.BlockingConnection(pika.ConnectionParameters(host=mq_host,port=mq_port,credentials=credentials))  
 
#在连接上创建一个频道
chan = s_conn.channel()
 
#声明一个队列（生产者和消费者都要声明一个相同的队列，用来防止万一某一方挂了，另一方能正常运行）
chan.queue_declare(queue=mq_queue1)     

while(1):
    for i in range(2):
        mq_body = json.dumps(generate_environmental_sensor_data(i))  

        #发送消息
        chan.basic_publish(exchange='', routing_key=mq_routing_key1, body=mq_body)

    print("[生产者] send '%s'"%mq_body)
    time.sleep(1)
 

 #关闭连接（当生产者发送完消息后，可选择关闭连接）
s_conn.close()
# Out:
# [生产者] send '{"timestamp": 1573635583156, "sensorID": 1, "temp": 26, "hum": 96, "pm2.5": 17, "pm10": 16, "co2": 77}'
# [生产者] send '{"timestamp": 1573635584156, "sensorID": 1, "temp": 11, "hum": 5, "pm2.5": 37, "pm10": 23, "co2": 25}'
# [生产者] send '{"timestamp": 1573635585157, "sensorID": 1, "temp": 13, "hum": 7, "pm2.5": 29, "pm10": 26, "co2": 22}'
# [生产者] send '{"timestamp": 1573635586157, "sensorID": 1, "temp": 12, "hum": 80, "pm2.5": 20, "pm10": 8, "co2": 45}'
# [生产者] send '{"timestamp": 1573635587158, "sensorID": 1, "temp": 2, "hum": 12, "pm2.5": 9, "pm10": 9, "co2": 96}'
# [生产者] send '{"timestamp": 1573635588158, "sensorID": 1, "temp": 11, "hum": 88, "pm2.5": 14, "pm10": 34, "co2": 34}'
# [生产者] send '{"timestamp": 1573635589159, "sensorID": 1, "temp": 21, "hum": 20, "pm2.5": 0, "pm10": 45, "co2": 42}'
# [生产者] send '{"timestamp": 1573635590160, "sensorID": 1, "temp": 12, "hum": 60, "pm2.5": 46, "pm10": 13, "co2": 6}'
# [生产者] send '{"timestamp": 1573635591163, "sensorID": 1, "temp": 11, "hum": 29, "pm2.5": 17, "pm10": 27, "co2": 41}'
# [生产者] send '{"timestamp": 1573635592163, "sensorID": 1, "temp": 8, "hum": 13, "pm2.5": 25, "pm10": 30, "co2": 34}'
# [生产者] send '{"timestamp": 1573635593165, "sensorID": 1, "temp": 26, "hum": 61, "pm2.5": 41, "pm10": 16, "co2": 67}'
# [生产者] send '{"timestamp": 1573635594166, "sensorID": 1, "temp": 14, "hum": 46, "pm2.5": 20, "pm10": 4, "co2": 53}'
# [生产者] send '{"timestamp": 1573635595167, "sensorID": 1, "temp": 18, "hum": 95, "pm2.5": 40, "pm10": 34, "co2": 24}'
# [生产者] send '{"timestamp": 1573635596168, "sensorID": 1, "temp": 18, "hum": 77, "pm2.5": 18, "pm10": 31, "co2": 57}'
# [生产者] send '{"timestamp": 1573635597169, "sensorID": 1, "temp": 7, "hum": 88, "pm2.5": 10, "pm10": 8, "co2": 65}'
# [生产者] send '{"timestamp": 1573635598171, "sensorID": 1, "temp": 5, "hum": 41, "pm2.5": 29, "pm10": 38, "co2": 76}'
# [生产者] send '{"timestamp": 1573635599171, "sensorID": 1, "temp": 16, "hum": 67, "pm2.5": 2, "pm10": 4, "co2": 40}'
# [生产者] send '{"timestamp": 1573635600172, "sensorID": 1, "temp": 8, "hum": 97, "pm2.5": 24, "pm10": 39, "co2": 43}'
# [生产者] send '{"timestamp": 1573635601173, "sensorID": 1, "temp": 11, "hum": 39, "pm2.5": 33, "pm10": 11, "co2": 31}'
# [生产者] send '{"timestamp": 1573635602174, "sensorID": 1, "temp": 29, "hum": 40, "pm2.5": 24, "pm10": 31, "co2": 37}'
# [生产者] send '{"timestamp": 1573635603175, "sensorID": 1, "temp": 27, "hum": 62, "pm2.5": 10, "pm10": 12, "co2": 82}'
# [生产者] send '{"timestamp": 1573635604175, "sensorID": 1, "temp": 28, "hum": 4, "pm2.5": 49, "pm10": 10, "co2": 85}'
# [生产者] send '{"timestamp": 1573635605175, "sensorID": 1, "temp": 19, "hum": 37, "pm2.5": 20, "pm10": 12, "co2": 15}'
# [生产者] send '{"timestamp": 1573635606175, "sensorID": 1, "temp": 21, "hum": 53, "pm2.5": 19, "pm10": 46, "co2": 14}'
# [生产者] send '{"timestamp": 1573635607176, "sensorID": 1, "temp": 11, "hum": 76, "pm2.5": 16, "pm10": 36, "co2": 67}'
# [生产者] send '{"timestamp": 1573635608176, "sensorID": 1, "temp": 4, "hum": 88, "pm2.5": 11, "pm10": 19, "co2": 3}'
# [生产者] send '{"timestamp": 1573635609178, "sensorID": 1, "temp": 13, "hum": 26, "pm2.5": 27, "pm10": 34, "co2": 96}'
# [生产者] send '{"timestamp": 1573635610180, "sensorID": 1, "temp": 4, "hum": 30, "pm2.5": 36, "pm10": 9, "co2": 3}'
# [生产者] send '{"timestamp": 1573635611180, "sensorID": 1, "temp": 16, "hum": 66, "pm2.5": 29, "pm10": 7, "co2": 66}'
# [生产者] send '{"timestamp": 1573635612182, "sensorID": 1, "temp": 6, "hum": 39, "pm2.5": 21, "pm10": 19, "co2": 34}'
# [生产者] send '{"timestamp": 1573635613184, "sensorID": 1, "temp": 12, "hum": 95, "pm2.5": 43, "pm10": 11, "co2": 97}'
# [生产者] send '{"timestamp": 1573635614185, "sensorID": 1, "temp": 17, "hum": 65, "pm2.5": 31, "pm10": 40, "co2": 94}'
# [生产者] send '{"timestamp": 1573635615186, "sensorID": 1, "temp": 27, "hum": 21, "pm2.5": 40, "pm10": 16, "co2": 73}'
# [生产者] send '{"timestamp": 1573635616186, "sensorID": 1, "temp": 2, "hum": 37, "pm2.5": 39, "pm10": 10, "co2": 76}'
# [生产者] send '{"timestamp": 1573635617187, "sensorID": 1, "temp": 15, "hum": 34, "pm2.5": 32, "pm10": 7, "co2": 91}'
# [生产者] send '{"timestamp": 1573635618187, "sensorID": 1, "temp": 22, "hum": 86, "pm2.5": 1, "pm10": 21, "co2": 3}'
# [生产者] send '{"timestamp": 1573635619190, "sensorID": 1, "temp": 17, "hum": 31, "pm2.5": 45, "pm10": 41, "co2": 41}'
# [生产者] send '{"timestamp": 1573635620191, "sensorID": 1, "temp": 11, "hum": 59, "pm2.5": 29, "pm10": 10, "co2": 57}'
# [生产者] send '{"timestamp": 1573635621191, "sensorID": 1, "temp": 24, "hum": 36, "pm2.5": 22, "pm10": 21, "co2": 89}'
# [生产者] send '{"timestamp": 1573635622192, "sensorID": 1, "temp": 9, "hum": 94, "pm2.5": 8, "pm10": 2, "co2": 54}'
# [生产者] send '{"timestamp": 1573635623193, "sensorID": 1, "temp": 9, "hum": 68, "pm2.5": 21, "pm10": 33, "co2": 5}'
# [生产者] send '{"timestamp": 1573635624194, "sensorID": 1, "temp": 27, "hum": 13, "pm2.5": 37, "pm10": 10, "co2": 92}'
# [生产者] send '{"timestamp": 1573635625195, "sensorID": 1, "temp": 13, "hum": 38, "pm2.5": 11, "pm10": 33, "co2": 27}'
# [生产者] send '{"timestamp": 1573635626196, "sensorID": 1, "temp": 11, "hum": 91, "pm2.5": 23, "pm10": 0, "co2": 92}'
# [生产者] send '{"timestamp": 1573635627197, "sensorID": 1, "temp": 28, "hum": 61, "pm2.5": 39, "pm10": 11, "co2": 83}'
# [生产者] send '{"timestamp": 1573635628197, "sensorID": 1, "temp": 27, "hum": 30, "pm2.5": 6, "pm10": 26, "co2": 2}'
# [生产者] send '{"timestamp": 1573635629198, "sensorID": 1, "temp": 21, "hum": 82, "pm2.5": 37, "pm10": 6, "co2": 13}'
# [生产者] send '{"timestamp": 1573635630198, "sensorID": 1, "temp": 21, "hum": 12, "pm2.5": 13, "pm10": 20, "co2": 21}'
# [生产者] send '{"timestamp": 1573635631199, "sensorID": 1, "temp": 25, "hum": 23, "pm2.5": 26, "pm10": 38, "co2": 73}'
# [生产者] send '{"timestamp": 1573635632200, "sensorID": 1, "temp": 12, "hum": 36, "pm2.5": 40, "pm10": 3, "co2": 66}'
# [生产者] send '{"timestamp": 1573635633200, "sensorID": 1, "temp": 24, "hum": 79, "pm2.5": 11, "pm10": 10, "co2": 85}'
# [生产者] send '{"timestamp": 1573635634201, "sensorID": 1, "temp": 7, "hum": 23, "pm2.5": 8, "pm10": 27, "co2": 15}'
# [生产者] send '{"timestamp": 1573635635201, "sensorID": 1, "temp": 7, "hum": 4, "pm2.5": 36, "pm10": 43, "co2": 63}'
# [生产者] send '{"timestamp": 1573635636202, "sensorID": 1, "temp": 18, "hum": 50, "pm2.5": 16, "pm10": 46, "co2": 34}'
# [生产者] send '{"timestamp": 1573635637203, "sensorID": 1, "temp": 5, "hum": 17, "pm2.5": 24, "pm10": 36, "co2": 32}'
# [生产者] send '{"timestamp": 1573635638203, "sensorID": 1, "temp": 8, "hum": 82, "pm2.5": 33, "pm10": 10, "co2": 49}'
# [生产者] send '{"timestamp": 1573635639204, "sensorID": 1, "temp": 25, "hum": 88, "pm2.5": 4, "pm10": 24, "co2": 31}'
# [生产者] send '{"timestamp": 1573635640204, "sensorID": 1, "temp": 21, "hum": 90, "pm2.5": 36, "pm10": 2, "co2": 53}'
# [生产者] send '{"timestamp": 1573635641206, "sensorID": 1, "temp": 16, "hum": 86, "pm2.5": 47, "pm10": 15, "co2": 27}'
# [生产者] send '{"timestamp": 1573635642208, "sensorID": 1, "temp": 29, "hum": 89, "pm2.5": 29, "pm10": 34, "co2": 45}'
# [生产者] send '{"timestamp": 1573635643210, "sensorID": 1, "temp": 18, "hum": 71, "pm2.5": 28, "pm10": 7, "co2": 36}'
# [生产者] send '{"timestamp": 1573635644211, "sensorID": 1, "temp": 23, "hum": 78, "pm2.5": 39, "pm10": 32, "co2": 31}'
# [生产者] send '{"timestamp": 1573635645212, "sensorID": 1, "temp": 21, "hum": 93, "pm2.5": 10, "pm10": 22, "co2": 17}'
# [生产者] send '{"timestamp": 1573635646212, "sensorID": 1, "temp": 2, "hum": 45, "pm2.5": 16, "pm10": 5, "co2": 71}'
# [生产者] send '{"timestamp": 1573635647213, "sensorID": 1, "temp": 24, "hum": 97, "pm2.5": 3, "pm10": 40, "co2": 39}'
# [生产者] send '{"timestamp": 1573635648214, "sensorID": 1, "temp": 23, "hum": 86, "pm2.5": 39, "pm10": 15, "co2": 0}'
# [生产者] send '{"timestamp": 1573635649215, "sensorID": 1, "temp": 4, "hum": 1, "pm2.5": 11, "pm10": 2, "co2": 85}'
# [生产者] send '{"timestamp": 1573635650216, "sensorID": 1, "temp": 7, "hum": 54, "pm2.5": 31, "pm10": 37, "co2": 8}'
# [生产者] send '{"timestamp": 1573635651217, "sensorID": 1, "temp": 11, "hum": 54, "pm2.5": 40, "pm10": 41, "co2": 12}'
